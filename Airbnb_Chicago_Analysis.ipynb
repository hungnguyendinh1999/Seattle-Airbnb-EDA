# %% [markdown]
# Introduction and Business Question.
# This cell will be used to write the prompt and the 3 business questions to this problem
#
# 1. (For users) What are the top factors that affects pricing? (Location, calendar time, amenities or reviews?)
# 2. (For hosts) What makes a good Airbnb? What factors do better reviews lodging have in common? What helps to get people to give good reviews?
# 3. (For both) When (should you book in advanced) is the busiest time in Seattle?
#     - may need to get Seattle holidays and events
#
# Link to Medium post: <a href="https://www.google.com/">yeah</a>

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# Directory browsing
import os
print(os.listdir('data'))
PROJECT_DIR = "." # os.getcwd()
DATA_DIR = PROJECT_DIR + '/data/'
DATA_DIR
# Out:
# ['reviews.csv', 'listings.csv', 'calendar.csv']
# './data/'

# %%
# retrieve Data
cal_df = pd.read_csv(DATA_DIR+'calendar.csv')
listings_df = pd.read_csv(DATA_DIR+'listings.csv')
reviews_df = pd.read_csv(DATA_DIR+'reviews.csv')

print(cal_df)
cal_df.sample(10)
# Out:
#          listing_id        date available    price
# 285546      6705584  2016-04-29         t  $105.00
# 1201400      158345  2016-07-07         t   $55.00
# 1119948      260613  2016-05-11         t  $135.00
# 105221      6466388  2016-04-14         t   $59.00
# 1036320     4077920  2016-03-29         f      NaN
# 8377        8942678  2016-12-16         t  $450.00
# 256312      8939503  2016-03-26         t   $49.00
# 530499      8068232  2016-06-06         t  $250.00
# 1049939     1775016  2016-07-21         f      NaN
# 409617      6363779  2016-03-31         f      NaN

# %%
listings_df.sample(5)
# drop listing_url, scrape_id, last_scraped
# Out:
#             id                            listing_url       scrape_id  \
# 2346  10188794  https://www.airbnb.com/rooms/10188794  20160104002432
# 2859   8050232   https://www.airbnb.com/rooms/8050232  20160104002432
# 2760   1562643   https://www.airbnb.com/rooms/1562643  20160104002432
# 2691   5030361   https://www.airbnb.com/rooms/5030361  20160104002432
# 75     3038772   https://www.airbnb.com/rooms/3038772  20160104002432
#
#      last_scraped                                 name  \
# 2346   2016-01-04           Bright Brand New Apartment
# 2859   2016-01-04   Studio apartment on lower cap hill
# 2760   2016-01-04  Renovated 1904 Capitol Hill classic
# 2691   2016-01-04         Vibrant Lively Urban Retreat
# 75     2016-01-04    Cozy Private Room, Bath and Patio
#
#                                                 summary  \
# 2346  One block from Lake Washington, close to Sewar...
# 2859  5 min walk to downtown and only 5 min from the...
# ...

# %%
reviews_df.sample(10)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 59995     9347157  56770680  2015-12-18      2849142         Jerry
# 71961     5470943  38262558  2015-07-14      2081540          Anne
# 16160      910784  26953721  2015-02-22     27298682         Mandy
# 6721       523883  19987673  2014-09-21     17420747      Kathleen
# 80725     6675927  37677252  2015-07-09       817507          Mary
# 27097     6691873  39199072  2015-07-21     36671849        Jordan
# 53500       30712   1661236  2012-07-08      2802249       Michael
# 44628      619366  34849770  2015-06-13     27634938       Ilyoung
# 78541     6746826  56195748  2015-12-10      2493722  Tom & Hannah
# 31067       59838  28985510  2015-04-02     23829766        Hemant
#
#                                                 comments
# 59995  The host canceled this reservation 193 days be...
# 71961  A gem of an apartment in a perfect location!  ...
# 16160  very nice house to，stay~close to downtown and ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df.columns[df.isna().all()]
# Out:
# Index(['license'], dtype='object')

# %% [markdown]
# Prepare data:
# - Gather necessary data to answer your questions
# - Handle categorical and missing data
# - Provide insight into the methods you chose and why you chose them

# %%
# remove all columns with only 1 value or all distinct values
# remove all columns/rows with ALL null?
cols = ['id','name','summary','space','description','instant_bookable',
        'neighborhood_overview','neighbourhood_cleansed','host_id','host_name','host_since',
        'host_response_time','review_scores_rating','property_type','room_type',
        'accommodates','bathrooms','bedrooms','beds','reviews_per_month','amenities','cancellation_policy','number_of_reviews','price']
print(len(cols))
cleaned_list_df = listings_df[cols]
cleaned_list_df.sample(5)
# Out:
# 24
#            id                                 name  \
# 3398  5444457  Bed&Bath in Charming Craftsman Home
# 3211  5306727    Cozy 1BD in the heart of the city
# 2618  1768883    Bright + Colorful in Capitol Hill
# 1617  5036739               Spacious Studio Condo
# 131   3121829  Kid friendly townhouse near it all
#
#                                                 summary  \
# 3398          This private Bed&Bath is located in a ...
# 3211  I am renting out my cozy 1 bedroom with master...
# 2618  This two bedroom apartment sits high above the...
# 1617  Spacious Studio Condo, located just steps from...
# 131   Just 4 blocks away from the Ballard library, m...
#
#                                                   space  \
# 3398  This private Bed & private Bath very comfortab...
# 3211  My apartment is a 2 bed 2 bath with shared liv...
# 2618  A few notes on our home: - It's our home, we l...
# 1617                                                NaN
# ...

# %%
# numerical columns
listings_df.dtypes == 'object'
['neighborhood_overview', '']
# Out:
# id                                  False
# listing_url                          True
# scrape_id                           False
# last_scraped                         True
# name                                 True
#                                     ...
# cancellation_policy                  True
# require_guest_profile_picture        True
# require_guest_phone_verification     True
# calculated_host_listings_count      False
# reviews_per_month                   False
# Length: 92, dtype: bool

# %%
# categorical columns

# %% [markdown]
# Analyze, Model, and Visualize \
# Provide a clear connection between your business questions and how the data answers them

# %% [markdown]
# ## Q1. (For users) What are the 3 top factors that affects pricing?
# We're considering typical factors like Location, time of year, and what the Airbnb provides.
#
# Link: https://www.airbnb.com/help/article/125/how-pricing-works
#
# Further tax in Washington: https://www.airbnb.com/help/article/2336/occupancy-tax-collection-and-remittance-by-airbnb-in-washington

# %%
# CLEAN: 

# LABEL : PRICING
# Histogram of prices

# %%
'''
NLP Wordcloud for 2 things:
1. listing description, name, summary, 


Group:
- Location
- Time of year

Histogram of prices

'''

# %%
# Conclusion:
# TOP 5 factors here

# %% [markdown]
# ## Q2. (For hosts) What makes a popular Airbnb?
# What makes a good Airbnb? What factors do better reviews lodging have in common? What helps to get people to give good reviews?

# %%
# DEFINITION
'''
'popular' means to be 
- highly booked (count num of times per year)
- average review is in 3.5 > stars
'''

# %%
'''

'''

# %% [markdown]
# ## Q3. (For both) When (should you book in advanced) is the busiest time in Seattle?
# - may need to get Seattle holidays and events
